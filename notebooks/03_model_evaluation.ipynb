# %% [markdown]
# # 03 - Baseline Model Evaluation
# Loads a trained baseline checkpoint and evaluates across S1-S7 (whichever sets are present under `data/doppler_traces/`).

# %%
import sys
sys.path.insert(0, '..')

from src.training.evaluate_baseline import main as evaluate_main

evaluate_main(
    config_path='../config/base_config.yaml',
    checkpoint_path='../outputs/baseline/checkpoints/sharp_baseline_best.pt',
)

# %%
# Inspect the per-set accuracy report written by evaluate_baseline.py
with open('../outputs/baseline/figures/per_set_accuracy.txt') as f:
    print(f.read())
