# %% [markdown]
# # 02 - Baseline Training
# Trains the SHARP baseline classifier on set S1 (60/20/20 split). Run `00_colab_setup.ipynb` first if on Colab.

# %%
import sys
sys.path.insert(0, '..')

from src.training.train_baseline import main as train_main

train_main(config_path='../config/base_config.yaml')
